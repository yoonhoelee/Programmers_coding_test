# %% [markdown]
# # 문제 설명
# n개의 섬 사이에 다리를 건설하는 비용(costs)이 주어질 때, 최소의 비용으로 모든 섬이 서로 통행 가능하도록 만들 때 필요한 최소 비용을 return 하도록 solution을 완성하세요.
#
# 다리를 여러 번 건너더라도, 도달할 수만 있으면 통행 가능하다고 봅니다. 예를 들어 A 섬과 B 섬 사이에 다리가 있고, B 섬과 C 섬 사이에 다리가 있으면 A 섬과 C 섬은 서로 통행 가능합니다.
#
# 제한사항
#
# 섬의 개수 n은 1 이상 100 이하입니다.
# costs의 길이는 ((n-1) * n) / 2이하입니다.
# 임의의 i에 대해, costs[i][0] 와 costs[i] [1]에는 다리가 연결되는 두 섬의 번호가 들어있고, costs[i] [2]에는 이 두 섬을 연결하는 다리를 건설할 때 드는 비용입니다.
# 같은 연결은 두 번 주어지지 않습니다. 또한 순서가 바뀌더라도 같은 연결로 봅니다. 즉 0과 1 사이를 연결하는 비용이 주어졌을 때, 1과 0의 비용이 주어지지 않습니다.
# 모든 섬 사이의 다리 건설 비용이 주어지지 않습니다. 이 경우, 두 섬 사이의 건설이 불가능한 것으로 봅니다.
# 연결할 수 없는 섬은 주어지지 않습니다.
#
# # 입출력 예
# n = 4
# costs = [[0,1,1],[0,2,2],[1,2,5],[1,3,1],[2,3,8]]
# return = 4
#
# # 입출력 예 설명
#
# costs를 그림으로 표현하면 다음과 같으며, 이때 초록색 경로로 연결하는 것이 가장 적은 비용으로 모두를 통행할 수 있도록 만드는 방법입니다.
#
# ![image.png](attachment:26c82c6a-1c89-4581-a3bf-aa72f354b284.png)![image.png](attachment:b41948a8-b2b6-468f-a797-0b391405a5ba.png)
#
# # 출처
# https://programmers.co.kr/learn/courses/30/lessons/42861?language=python3

# %%
def solution(n, costs):
    ans = 0
    costs.sort(key = lambda x: x[2])
    routes = set([costs[0][0]])
    while len(routes)!=n:
        for i, cost in enumerate(costs):
            if cost[0] in routes and cost[1] in routes:
                continue
            if cost[0] in routes or cost[1] in routes:
                routes.update([cost[0], cost[1]])
                ans += cost[2]
                costs[i] = [-1, -1, -1]
                break
    return ans

solution(4, [[0,1,1],[0,2,2],[1,2,5],[1,3,1],[2,3,8]])
# Out:
# 4

# %% [markdown]
# # 풀이
# 크루스칼 알고리즘을 활용해 비용 기준으로 오름차순을 선정해주고, routes라는 set를 만들어 경로들을 확인할 수 있는 변수를 확인할 수 있게 해준다. 이 오름차순을 진행한 리스트를 enumerate 해주고 반복문을 돌게하여 루트를 추가해주고 cost를 더해준다. 이때 주의할건 사이클이 생성되지 않게하기 위해 간선의 양끝점이 같은 집합에 속하지 않게 하는 것이다.
#
# # 느낀점
# 처음으로 풀어 본 프로그래머스의 레벨3 문제였는데 쉽지 않았다. 약간의 검색 이후 탐욕법을 활용해 여러 구간을 최소비용으로 연결하는 크루스칼 알고리즘에 대해서 알게 되었고, 이 방법을 적용하니 비교적 간단하게 풀렸다. 역시 아직 공부할 내용이 많아 보인다.
